# %%
#!python run.py "QFT_wsq_8_compiled" "SHAW" "G2x3" "3" "2" "FM" 0
#!python QCCD_schedule.py

# %%
a = 2 
b = 3
a, b = b, a

# %%
a, b
# Out:
# (3, 2)

# %%
# !python QCCDSim/run.py "QAOA_wsq_8_compiled" "H" "3" "Greedy" "Naive" "1" "0" "0" "FM" "GateSwap"
# Out:
# Simulation
# Program: /work/acslab/users/baobach/bqskit-shuttling/bqskit/shuttling/qccd/benchmark_circuits/QAOA_wsq_8_compiled.qasm
# Machine: H
# Model: MPar3
# Ions: 3
# Mapper: Greedy
# Reorder: Naive
# SerialTrap: 1
# SerialComm: 0
# SerialAll: 0
# Gatetype: FM
# Swaptype: GateSwap
# Trap capacity:  3
# Trap capacity:  3
# Trap capacity:  3
# Trap capacity:  3
# qbit 1: 0 qbit 2: 7 dep gates: 0
# qbit 1: 0 qbit 2: 7 dep gates: 0
# qbit 1: 1 qbit 2: 5 dep gates: 1
# qbit 1: 1 qbit 2: 5 dep gates: 1
# qbit 1: 3 qbit 2: 6 dep gates: 2
# qbit 1: 3 qbit 2: 6 dep gates: 2
# qbit 1: 1 qbit 2: 7 dep gates: 4
# qbit 1: 1 qbit 2: 7 dep gates: 3
# qbit 1: 4 qbit 2: 6 dep gates: 5
# qbit 1: 2 qbit 2: 5 dep gates: 4
# qbit 1: 1 qbit 2: 7 dep gates: 6
# qbit 1: 1 qbit 2: 7 dep gates: 6
# qbit 1: 4 qbit 2: 6 dep gates: 7
# qbit 1: 4 qbit 2: 6 dep gates: 7
# qbit 1: 2 qbit 2: 5 dep gates: 8
# qbit 1: 2 qbit 2: 5 dep gates: 8
# qbit 1: 3 qbit 2: 7 dep gates: 5
# qbit 1: 3 qbit 2: 7 dep gates: 9
# ...

# %%
# !python run_gates.py "QFT_8_compiled" "SHAPER" "H" "3" "2" "FM" 0
# Out:
# Input filename:  QFT_8_compiled
# Algorithm:  SHAPER
# Trap type:  H
# Trap capacity:  3
# Num layout passes:  2
# Gate type:  FM
# Run index:  0
# Creating a QCCD machine ...
# QCCD physical machine:
# ### Traps ###
# Trap(id='trap_0', max_num_ions=3, initial_num_ions=0, executable=True, measureable=False)
# Trap(id='trap_1', max_num_ions=3, initial_num_ions=0, executable=True, measureable=True)
# Trap(id='trap_2', max_num_ions=3, initial_num_ions=0, executable=True, measureable=False)
# Trap(id='trap_3', max_num_ions=3, initial_num_ions=0, executable=True, measureable=True)
# ### Junctions ###
# Junction(id='junction_0')
# Junction(id='junction_1')
# ### Segments ###
# Segment(id='segment_0', left=Trap(id='trap_0', max_num_ions=3, initial_num_ions=0, executable=True, measureable=False), right=Junction(id='junction_0'))
# Segment(id='segment_1', left=Trap(id='trap_1', max_num_ions=3, initial_num_ions=0, executable=True, measureable=True), right=Junction(id='junction_0'))
# ...

# %%
0.999**(47)
# Out:
# 0.954064961841736
